# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Cause of death due to injury

# %%
cod_injury_stats = "Resources/cod_injury_stats.csv"

# %%
cod_stats_df = pd.read_csv(cod_injury_stats, low_memory=False, error_bad_lines=False)

# %%
cod_stats_df
# Out:
#      Country Name Country Code                          Indicator Name  \
# 0           Aruba          ABW  Cause of death, by injury (% of total)
# 1     Afghanistan          AFG  Cause of death, by injury (% of total)
# 2          Angola          AGO  Cause of death, by injury (% of total)
# 3         Albania          ALB  Cause of death, by injury (% of total)
# 4         Andorra          AND  Cause of death, by injury (% of total)
# ..            ...          ...                                     ...
# 259        Kosovo          XKX  Cause of death, by injury (% of total)
# 260   Yemen, Rep.          YEM  Cause of death, by injury (% of total)
# 261  South Africa          ZAF  Cause of death, by injury (% of total)
# 262        Zambia          ZMB  Cause of death, by injury (% of total)
# 263      Zimbabwe          ZWE  Cause of death, by injury (% of total)
#
#      Indicator Code  2000  2010  2015  2016
# 0    SH.DTH.INJR.ZS   NaN   NaN   NaN   NaN
# ...

# %%
clean_cod= cod_stats_df.dropna()
clean_cod
# Out:
#              Country Name Country Code  \
# 1             Afghanistan          AFG
# 2                  Angola          AGO
# 3                 Albania          ALB
# 5              Arab World          ARB
# 6    United Arab Emirates          ARE
# ..                    ...          ...
# 258                 Samoa          WSM
# 260           Yemen, Rep.          YEM
# 261          South Africa          ZAF
# 262                Zambia          ZMB
# 263              Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       2000  \
# 1    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS  10.000000
# 2    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS   7.200000
# 3    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS   8.000000
# 5    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS   9.415963
# 6    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS  18.200000
# ...

# %%
Avg=clean_cod.mean(axis=1)
Avg
# Out:
# 1      13.700000
# 2       8.500000
# 3       5.325000
# 5      11.912084
# 6      18.675000
#          ...
# 258     7.900000
# 260    13.925000
# 261     9.400000
# 262     8.650000
# 263     9.800000
# Length: 229, dtype: float64

# %%
avg_df= pd.DataFrame(Avg)
avg_df
# Out:
#              0
# 1    13.700000
# 2     8.500000
# 3     5.325000
# 5    11.912084
# 6    18.675000
# ..         ...
# 258   7.900000
# 260  13.925000
# 261   9.400000
# 262   8.650000
# 263   9.800000
#
# [229 rows x 1 columns]

# %%
clean_cod= pd.merge(clean_cod, avg_df, left_index=True, right_index=True)
clean_cod
# Out:
#              Country Name Country Code  \
# 1             Afghanistan          AFG
# 2                  Angola          AGO
# 3                 Albania          ALB
# 5              Arab World          ARB
# 6    United Arab Emirates          ARE
# ..                    ...          ...
# 258                 Samoa          WSM
# 260           Yemen, Rep.          YEM
# 261          South Africa          ZAF
# 262                Zambia          ZMB
# 263              Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       2000  \
# 1    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS  10.000000
# 2    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS   7.200000
# 3    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS   8.000000
# 5    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS   9.415963
# 6    Cause of death, by injury (% of total)  SH.DTH.INJR.ZS  18.200000
# ...

# %%
clean_cod_2 = clean_cod.rename(columns={"Country Name": "country_name", "Country Code": "country_code", 0:"average_per"})

# %%
columns= ["country_code", "average_per"]

injury= clean_cod_2[columns].copy()
injury
# Out:
#     country_code  average_per
# 1            AFG    13.700000
# 2            AGO     8.500000
# 3            ALB     5.325000
# 5            ARB    11.912084
# 6            ARE    18.675000
# ..           ...          ...
# 258          WSM     7.900000
# 260          YEM    13.925000
# 261          ZAF     9.400000
# 262          ZMB     8.650000
# 263          ZWE     9.800000
#
# [229 rows x 2 columns]

# %%
injury.index.rename("id", inplace=True)
injury
# Out:
#     country_code  average_per
# id
# 1            AFG    13.700000
# 2            AGO     8.500000
# 3            ALB     5.325000
# 5            ARB    11.912084
# 6            ARE    18.675000
# ..           ...          ...
# 258          WSM     7.900000
# 260          YEM    13.925000
# 261          ZAF     9.400000
# 262          ZMB     8.650000
# 263          ZWE     9.800000
#
# [229 rows x 2 columns]

# %% [markdown]
# ## Non Communicable diseases

# %%
non_com_dis ="Resources/non_com.csv"

# %%
non_com_dis_df = pd.read_csv(non_com_dis, low_memory=False, error_bad_lines=False)
non_com_dis_df
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Cause of death, by non-communicable diseases (...  SH.DTH.NCOM.ZS   NaN
# 1    Cause of death, by non-communicable diseases (...  SH.DTH.NCOM.ZS   NaN
# 2    Cause of death, by non-communicable diseases (...  SH.DTH.NCOM.ZS   NaN
# 3    Cause of death, by non-communicable diseases (...  SH.DTH.NCOM.ZS   NaN
# 4    Cause of death, by non-communicable diseases (...  SH.DTH.NCOM.ZS   NaN
# ..                                                 ...             ...   ...
# ...

# %%
non_com_col=["Country Name", "Country Code", "2000", "2010", "2015", "2016"]
non_com_df= non_com_dis_df[non_com_col].copy()
non_com_df
# Out:
#      Country Name Country Code  2000  2010  2015  2016
# 0           Aruba          ABW   NaN   NaN   NaN   NaN
# 1     Afghanistan          AFG  28.6  39.2  44.8  44.1
# 2          Angola          AGO  18.0  23.2  27.2  27.4
# 3         Albania          ALB  84.7  91.3  93.1  93.1
# 4         Andorra          AND   NaN   NaN   NaN   NaN
# ..            ...          ...   ...   ...   ...   ...
# 259        Kosovo          XKX   NaN   NaN   NaN   NaN
# 260   Yemen, Rep.          YEM  43.8  55.2  53.4  56.6
# 261  South Africa          ZAF  40.3  39.8  50.8  51.3
# 262        Zambia          ZMB  16.1  24.1  28.3  29.2
# 263      Zimbabwe          ZWE  18.6  24.2  31.7  33.0
#
# [264 rows x 6 columns]

# %%
non_com_clean=non_com_df.dropna()

# %%
non_com_df["average_per"]=non_com_clean.mean(axis=1)
non_com_df=non_com_df.dropna()
non_com_df
# Out:
#              Country Name Country Code       2000       2010       2015  \
# 1             Afghanistan          AFG  28.600000  39.200000  44.800000
# 2                  Angola          AGO  18.000000  23.200000  27.200000
# 3                 Albania          ALB  84.700000  91.300000  93.100000
# 5              Arab World          ARB  58.352298  65.595203  65.113017
# 6    United Arab Emirates          ARE  71.300000  70.400000  75.700000
# ..                    ...          ...        ...        ...        ...
# 258                 Samoa          WSM  76.200000  77.500000  80.500000
# 260           Yemen, Rep.          YEM  43.800000  55.200000  53.400000
# 261          South Africa          ZAF  40.300000  39.800000  50.800000
# 262                Zambia          ZMB  16.100000  24.100000  28.300000
# 263              Zimbabwe          ZWE  18.600000  24.200000  31.700000
#
#           2016  average_per
# 1    44.100000     39.17500
# 2    27.400000     23.95000
# ...

# %%
non_communicable_df= non_com_df.rename(columns={"Country Name": "country_name", "Country Code": "country_code"})
non_communicable_df
# Out:
#              country_name country_code       2000       2010       2015  \
# 1             Afghanistan          AFG  28.600000  39.200000  44.800000
# 2                  Angola          AGO  18.000000  23.200000  27.200000
# 3                 Albania          ALB  84.700000  91.300000  93.100000
# 5              Arab World          ARB  58.352298  65.595203  65.113017
# 6    United Arab Emirates          ARE  71.300000  70.400000  75.700000
# ..                    ...          ...        ...        ...        ...
# 258                 Samoa          WSM  76.200000  77.500000  80.500000
# 260           Yemen, Rep.          YEM  43.800000  55.200000  53.400000
# 261          South Africa          ZAF  40.300000  39.800000  50.800000
# 262                Zambia          ZMB  16.100000  24.100000  28.300000
# 263              Zimbabwe          ZWE  18.600000  24.200000  31.700000
#
#           2016  average_per
# 1    44.100000     39.17500
# 2    27.400000     23.95000
# ...

# %%
non_com_col= ["country_code", "average_per"]

non_comm= non_communicable_df[non_com_col].copy()
non_comm
# Out:
#     country_code  average_per
# 1            AFG     39.17500
# 2            AGO     23.95000
# 3            ALB     90.55000
# 5            ARB     63.81353
# 6            ARE     73.55000
# ..           ...          ...
# 258          WSM     78.80000
# 260          YEM     52.25000
# 261          ZAF     45.55000
# 262          ZMB     24.42500
# 263          ZWE     26.87500
#
# [229 rows x 2 columns]

# %%
non_comm.index.rename("id", inplace=True)
non_comm
# Out:
#     country_code  average_per
# id
# 1            AFG     39.17500
# 2            AGO     23.95000
# 3            ALB     90.55000
# 5            ARB     63.81353
# 6            ARE     73.55000
# ..           ...          ...
# 258          WSM     78.80000
# 260          YEM     52.25000
# 261          ZAF     45.55000
# 262          ZMB     24.42500
# 263          ZWE     26.87500
#
# [229 rows x 2 columns]

# %% [markdown]
# ## Country

# %%
countries_in ="Resources/income_group.csv"

# %%
countries_df = pd.read_csv(countries_in, low_memory=False, error_bad_lines=False)

# %%
countries_df=countries_df.rename(columns={"Region": "region", "Country Code": "country_code"})

# %%
country_cols= ["country_code", "region"]
country_df= countries_df[country_cols].copy()
country_df
# Out:
#     country_code                      region
# 0            ABW   Latin America & Caribbean
# 1            AFG                  South Asia
# 2            AGO          Sub-Saharan Africa
# 3            ALB       Europe & Central Asia
# 4            AND       Europe & Central Asia
# ..           ...                         ...
# 258          XKX       Europe & Central Asia
# 259          YEM  Middle East & North Africa
# 260          ZAF          Sub-Saharan Africa
# 261          ZMB          Sub-Saharan Africa
# 262          ZWE          Sub-Saharan Africa
#
# [263 rows x 2 columns]

# %%
country=pd.merge(country_df, non_communicable_df, on="country_code")
country
# Out:
#     country_code                      region          country_name       2000  \
# 0            AFG                  South Asia           Afghanistan  28.600000
# 1            AGO          Sub-Saharan Africa                Angola  18.000000
# 2            ALB       Europe & Central Asia               Albania  84.700000
# 3            ARB                         NaN            Arab World  58.352298
# 4            ARE  Middle East & North Africa  United Arab Emirates  71.300000
# ..           ...                         ...                   ...        ...
# 224          WSM         East Asia & Pacific                 Samoa  76.200000
# 225          YEM  Middle East & North Africa           Yemen, Rep.  43.800000
# 226          ZAF          Sub-Saharan Africa          South Africa  40.300000
# 227          ZMB          Sub-Saharan Africa                Zambia  16.100000
# 228          ZWE          Sub-Saharan Africa              Zimbabwe  18.600000
#
# ...

# %%
country_cols_2=["country_code", "region", "country_name"]
country = country[country_cols_2].copy()
country
# Out:
#     country_code                      region          country_name
# 0            AFG                  South Asia           Afghanistan
# 1            AGO          Sub-Saharan Africa                Angola
# 2            ALB       Europe & Central Asia               Albania
# 3            ARB                         NaN            Arab World
# 4            ARE  Middle East & North Africa  United Arab Emirates
# ..           ...                         ...                   ...
# 224          WSM         East Asia & Pacific                 Samoa
# 225          YEM  Middle East & North Africa           Yemen, Rep.
# 226          ZAF          Sub-Saharan Africa          South Africa
# 227          ZMB          Sub-Saharan Africa                Zambia
# 228          ZWE          Sub-Saharan Africa              Zimbabwe
#
# [229 rows x 3 columns]

# %% [markdown]
# ## FOR SQL

# %%
connection_string = "postgres:postgres@localhost:5432/Project_2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
country.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
injury.to_sql(name='injury', con=engine, if_exists='append', index=True)

# %%
injury.head()

# %%
non_comm.to_sql(name='non_comm', con=engine, if_exists='append', index=True)
