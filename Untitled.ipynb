# %%
import pandas as pd

# %%
data = pd.read_csv("table.csv")

# %%
data
# Out:
#       Table        Column                                        Description  \
# 0   Country  country_code  The Krimary Key for this table, a code for eac...
# 1   Country  country_name                           The name of the country.
# 2   Country        region    The region of the world the country belongs to.
# 3    Injury            ID                                    The Primary Key
# 4    Injury  country_code                   The Foreign Key of Country table
# 5    Injury   Average_per  Average of deaths by injury for 2000, 2010, 20...
# 6  non_comm            ID                                    The Primary Key
# 7  non_comm  country_code                   The Foreign Key of Country table
# 8  non_comm   Average_per  Average of deaths by non communicable diceases...
#
#       Type
# 0  varchar
# 1  varchar
# 2  varchar
# 3  integer
# 4  varchar
# 5  integer
# 6  integer
# 7  varchar
# 8  integer

# %%
data.set_index('Table', inplace=True)

# %%
data
# Out:
#                 Column                                        Description  \
# Table
# Country   country_code  The Krimary Key for this table, a code for eac...
# Country   country_name                           The name of the country.
# Country         region    The region of the world the country belongs to.
# Injury              ID                                    The Primary Key
# Injury    country_code                   The Foreign Key of Country table
# Injury     Average_per  Average of deaths by injury for 2000, 2010, 20...
# non_comm            ID                                    The Primary Key
# non_comm  country_code                   The Foreign Key of Country table
# non_comm   Average_per  Average of deaths by non communicable diceases...
#
#              Type
# Table
# Country   varchar
# Country   varchar
# Country   varchar
# Injury    integer
# Injury    varchar
# Injury    integer
# non_comm  integer
# non_comm  varchar
# non_comm  integer
